# %%
from NeuralNetwork import NeuralNetwork, VGG1
from Dataset import Dataset
from NeuroEvolution import NeuroEvolution
from tensorflow import keras
from Representation import Function
from Activation import PANGAEA_Activation, Pade_Activation_Unit
import tensorflow as tf
import numpy as np
import pandas as pd
import time

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
num_classes = 10
input_shape = (28, 28, 1)
mnist_dataset = Dataset(X_train, y_train, X_test, y_test, num_classes, input_shape, expand=True, label_noise=0)

model_vgg1 = VGG1(mnist_dataset)

# %%
loss = Function([1, 15, 26, 1, 3, 9, 30, 8, 17])
activation =  PANGAEA_Activation([6, 19, 26, 3, 5, 9, 19, 22, 28])
gradient = Function([1, 31, 31, 1, 1, 31, 31, 31, 31])
optimizer = tf.optimizers.Adam()
dropout = 0.5
metric = metric = keras.metrics.CategoricalAccuracy()
batch_size = 128
epochs = 100
patience = np.inf 
verbose = 0


model_vgg1.set_config(loss, activation, gradient, optimizer, dropout, metric, batch_size, epochs, patience, verbose)
model_vgg1.create_model()

# %%
model_vgg1.fit()
# Out:
# Start of epoch 0
# Training acc: 0.8886
# Validation acc: 0.9827
# Time taken: 5.24s
#
# Start of epoch 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-f1cb5074abcc> in <module>
# ----> 1 model_vgg1.fit()
#
# ~\PycharmProjects\SANE - V1\NeuralNetwork.py in fit(self)
#      81             for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
#      82                 # print(type(epoch), type(train_step_counter))
# ---> 83                 loss_value = train_step(x_batch_train, y_batch_train, epoch + 1, False)
#      84                 train_step_counter += 1
#      85             # print(train_step_counter)
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
log, population = NeuroEvolution.SAGA_V0([model_vgg1],
                                             schedule='epoch',
                                             representation='pangaea',
                                             populationSize=10, 
                                             reductionRate=1,
                                             pateince=1,
                                             tolerance=2,
                                             d=4,
                                             epochs=epochs,
                                             maxNoChange=10, #np.inf,
                                             initilizationMax=2,
                                             verbose=1,
                                             starting_epoch=1,
                                             
                                             include=False,
                                             #targetFitness=target_loss,
                                             optimizationTask='activation',
                                             evaluation='validation',
                                             metric='accuracy',
                                             timeout=3000) #np.inf)

# %%
from deap import tools
from Activation import PANGAEA_Activation

pop_size = 20
counter = 1
epochs_v = 1
sample_v = mnist_dataset.X_train.shape[0]
epoch_level = 1
relu = Function([5, 7, 9, 1, 1, 7, 7, 9, 7])
dropout = 0.2
saga_log_df = pd.DataFrame(columns=(('time', 'val_accuracy', 'test_accuracy', 'activation', 'loss')))
times = 20

earlyTermination = pd.DataFrame(columns=('epochs', 'min_fitness'))
while epoch_level < epochs:
            row = [epoch_level, -1 * np.inf]
            earlyTermination.loc[len(earlyTermination)] = row
            epoch_level = epoch_level * 2
row = [epochs, -1 * np.inf]
earlyTermination.loc[len(earlyTermination)] = row

#timeout=60
t = time.time_ns()
saga_dfs = []
chc_dfs = []

#[1, 7, 10, 1, 1, 7, 7, 7, 18])
#loss_neg = Function([3, 13, 10, 2, 1, 8, 9, 7, 18])

population_pos = NeuroEvolution.createPopulation(pop_size, None)
population_neg = NeuroEvolution.createPopulation(pop_size, None)

#model = MNISTVGG1(X_train, y_train, X_test, y_test, relu, (Function(loss_pos), Function(loss_neg)), 10, inputShape, True, 0.5)



loss = None
activation = None



stop = 0.93

d_pos = 4
d_neg = 4

best = 0

loss_pos = [1, 31, 31, 1, 1, 31, 31, 31, 31]
loss_neg = [1, 31, 31, 1, 1, 31, 31, 31, 31]

epoch_change = False

start = time.time()

while counter <= 10:
   
    print('Current surrogate: epochs', epochs_v, ', samples', sample_v)
    print('Evolving loss:')
    log, population_neg = NeuroEvolution.CHC([model_vgg1],
                                        earlyTermination=earlyTermination,
                                        representation='loss',
                                        population=population_neg, 
                                        populationSize=pop_size,
                                        d=d_neg, 
                                        epochs=epochs_v,
                                        sampleSize=sample_v,
                                        divergence=3,
                                        maxGenerations=2,
                                        optimizationTask='loss',
                                        evaluation='validation',
                                        metric='accuracy',
                                        #stop=stop,
                                        verbose=0,
                                        timeout=np.inf) #np.inf)
       
    if not activation:
        loss = log.iloc[-1]['best_solution']    
    elif loss != log.iloc[-1]['best_solution'] and activation:
        if (epochs_v < epochs):
            model_vgg1.set_config(Function(log.iloc[-1]['best_solution']), PANGAEA_Activation(activation), gradient, optimizer, dropout, metric, batch_size, epochs, patience, verbose)
            model_vgg1.create_model()
            model_vgg1.fit()
            fitness = model_vgg1.val_score


        else:
            fitness = log.iloc[-1]['best_fitness']
            
        if (fitness > best):
            loss = log.iloc[-1]['best_solution']
            print()
            print('activation:', activation, ', loss:', loss)
            print('New best:', fitness)   
            print()
            best = fitness
            end = time.time()
            row = [end-start, model_vgg1.val_score, model_vgg1.test_score, activation, loss]
            saga_log_df.loc[len(saga_log_df)] = row
            print(row)
            del model_vgg1
        else:
            print('No improvements:', fitness)
            
    model_vgg1 = VGG1(mnist_dataset)
    model_vgg1.set_config(Function(loss), PANGAEA_Activation([5, 7, 9, 1, 1, 7, 7, 9, 7]), gradient, optimizer, dropout, metric, batch_size, epochs, patience, verbose)
    model_vgg1.create_model()
    
    stop = log.iloc[-1]['best_fitness']
    d_neg = log.iloc[-1]['d']
    
    print('Evolving activation:')
    log, population_pos = NeuroEvolution.CHC([model_vgg1],
                                        earlyTermination=earlyTermination,
                                        representation='pangaea',
                                        population=population_pos, 
                                        populationSize=pop_size,
                                        d=d_pos, 
                                        epochs=epochs_v,
                                        sampleSize=sample_v,
                                        divergence=3,
                                        maxGenerations=2,
                                        optimizationTask='activation',
                                        evaluation='validation',
                                        metric='accuracy',
                                        #stop=stop,
                                        verbose=0,
                                        timeout=np.inf) #np.inf)
    
    if not loss:
        activation = log.iloc[-1]['best_solution']
        
    elif activation != log.iloc[-1]['best_solution'] and loss:
        if (epochs_v < epochs):
            model_vgg1.set_config(Function(loss), PANGAEA_Activation(log.iloc[-1]['best_solution']), gradient, optimizer, dropout, metric, batch_size, epochs, patience, verbose)
            model_vgg1.create_model()
            model_vgg1.fit()
            fitness = model_vgg1.val_score
   
        else:
            fitness = log.iloc[-1]['best_fitness']
        if (fitness > best):
            activation = log.iloc[-1]['best_solution']
            print()
            print('activation:', activation, ', loss:', loss)
            print('New best:', fitness)    
            print()
            best = fitness
            end = time.time()
            row = [end-start, model_vgg1.val_score, model_vgg1.test_score, activation, loss]
            saga_log_df.loc[len(saga_log_df)] = row
            print(row)
            del model_vgg1
        else:
            print('No improvements:', fitness)
            
    model_vgg1 = VGG1(mnist_dataset)
    model_vgg1.set_config(Function(loss), PANGAEA_Activation(activation), gradient, optimizer, dropout, metric, batch_size, epochs, patience, verbose)
    model_vgg1.create_model()
        
    stop = log.iloc[-1]['best_fitness']
    d_pos = log.iloc[-1]['d']
    

    
    if (pop_size > 8):
        pop_size = pop_size //2
    else:
        pop_size = 4
        
    if (epochs_v != epochs):    
        if (epochs_v * 2 < epochs):
            epochs_v = epochs_v * 2
        else:
            epochs_v = epochs
    
    if (sample_v != model_vgg1.dataset.X_train.shape[0]):    
        if (sample_v * 2 < model.X_train.shape[0]):
            sample_v = sample_v * 2
        else:
            sample_v = model.X_train.shape[0]

    population_pos = tools.selBest(population_pos, pop_size)
    population_neg = tools.selBest(population_neg, pop_size)


    
    for individual in population_pos:
        individual.fitness.values = NeuroEvolution.evaluate(individual, models=[model_vgg1], 
                                      earlyTermination=earlyTermination, representation='pangaea', 
                                      epochs=epochs_v, sampleSize=sample_v, 
                                      optimizationTask='activation', evaluation='validation', metric='accuracy')
   

    for individual in population_neg:
        individual.fitness.values = NeuroEvolution.evaluate(individual, models=[model_vgg1], 
                                      earlyTermination=earlyTermination, representation='loss', 
                                      epochs=epochs_v, sampleSize=sample_v, 
                                      optimizationTask='loss', evaluation='validation', metric='accuracy')
# Out:
# Current surrogate: epochs 1 , samples 54000
# Evolving loss:
# [2, 27, 9, 1, 4, 9, 31, 25, 16] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.09783333539962769 0.09799999743700027
# [6, 28, 24, 2, 5, 18, 25, 31, 12] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.21016666293144226 0.20170000195503235
# [1, 16, 22, 6, 6, 22, 8, 19, 13] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.0016666667070239782 0.0008999999845400453
# [4, 24, 7, 4, 1, 13, 16, 14, 13] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.09783333539962769 0.09799999743700027
# [5, 19, 7, 3, 2, 29, 13, 30, 16] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.9854999780654907 0.9815000295639038
# [5, 25, 14, 5, 1, 13, 16, 30, 27] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.09783333539962769 0.09799999743700027
# [5, 17, 27, 2, 5, 22, 18, 29, 8] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.09783333539962769 0.09799999743700027
# [1, 20, 20, 4, 1, 11, 26, 20, 15] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.98416668176651 0.982200026512146
# [1, 23, 20, 4, 2, 7, 8, 17, 26] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.984333336353302 0.9807000160217285
# [3, 13, 10, 5, 3, 11, 7, 14, 24] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.09783333539962769 0.09799999743700027
# [4, 14, 26, 4, 6, 22, 19, 21, 16] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.09783333539962769 0.09799999743700027
# [6, 20, 12, 4, 3, 7, 7, 28, 8] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.07500000298023224 0.06629999727010727
# [2, 13, 19, 1, 3, 8, 13, 10, 19] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.9854999780654907 0.9805999994277954
# [6, 23, 11, 3, 5, 17, 15, 17, 30] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.9848333597183228 0.9807999730110168
# [3, 21, 30, 5, 3, 21, 24, 27, 14] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.09783333539962769 0.09799999743700027
# [3, 19, 10, 1, 4, 21, 21, 8, 27] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0.9838333129882812 0.9818000197410583
# [2, 16, 18, 1, 5, 15, 29, 9, 20] [6, 19, 26, 3, 5, 9, 19, 22, 28]
# 0
)
# [1, 20, 11, 4, 3, 8, 15, 31, 12] (0.9946666955947876,)
# [1, 23, 20, 4, 3, 8, 15, 31, 26] (0.9940000176429749,)
# [2, 20, 11, 3, 3, 8, 15, 31, 12] (0.9929999709129333,)
#
# [1, 23, 20, 3, 3, 8, 15, 31, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9925000071525574 0.991599977016449
# [2, 23, 20, 4, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.0006666666595265269 0.0003000000142492354
# False
# 0.99 number of paired: 1 number of mutations: 0  d: 3  no change: 2
#
# Evolving activation:
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9956666827201843,)
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9950000047683716,)
# [2, 21, 7, 2, 4, 30, 21, 27, 27] (0.9931666851043701,)
# [2, 21, 7, 2, 4, 30, 21, 17, 23] (0.9936666488647461,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 8, 7, 2, 3, 30, 21, 27, 27]
# 0.10499999672174454 0.11349999904632568
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 7, 3, 3, 30, 21, 27, 27]
# 0.10499999672174454 0.11349999904632568
# True
# 1.0 number of paired: 1 number of mutations: 0  d: 3  no change: 1
#
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9956666827201843,)
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9950000047683716,)
# [2, 21, 7, 2, 4, 30, 21, 17, 23] (0.9936666488647461,)
# [2, 21, 7, 2, 4, 30, 21, 27, 27] (0.9931666851043701,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 27, 27]
# 0.9958333373069763 0.9939000010490417
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 7, 3, 3, 30, 21, 17, 23]
# 0.10499999672174454 0.11349999904632568
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 7, 3, 3, 30, 21, 17, 27]
# 0.10499999672174454 0.11349999904632568
# True
# 1.0 number of paired: 2 number of mutations: 0  d: 3  no change: 0
#
# No improvements: 0.9950000047683716
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 27, 27]
# 0.9963333606719971 0.9941999912261963
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 17, 23]
# 0.9958333373069763 0.9944999814033508
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9953333139419556 0.9939000010490417
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 30, 21, 17, 23]
# 0.9933333396911621 0.9926999807357788
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9953333139419556 0.9930999875068665
# [1, 20, 11, 4, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9938333630561829 0.9933000206947327
# [1, 23, 20, 4, 3, 8, 15, 31, 26] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9928333163261414 0.9922000169754028
# [2, 20, 11, 3, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9934999942779541 0.9929999709129333
# Current surrogate: epochs 64 , samples 54000
# Evolving loss:
# [2, 23, 11, 3, 3, 8, 15, 17, 19] (0.9953333139419556,)
# [1, 20, 11, 4, 3, 8, 15, 31, 12] (0.9938333630561829,)
# [1, 23, 20, 4, 3, 8, 15, 31, 26] (0.9928333163261414,)
# [2, 20, 11, 3, 3, 8, 15, 31, 12] (0.9934999942779541,)
#
# [2, 20, 11, 4, 3, 8, 15, 31, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9940000176429749 0.9932000041007996
# [1, 23, 11, 3, 3, 8, 15, 17, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9936666488647461 0.9921000003814697
# [2, 23, 11, 4, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9933333396911621 0.991599977016449
# [1, 23, 20, 3, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9934999942779541 0.9926999807357788
# True
# 1.0 number of paired: 2 number of mutations: 0  d: 4  no change: 1
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] (0.9953333139419556,)
# [2, 20, 11, 4, 3, 8, 15, 31, 19] (0.9940000176429749,)
# [1, 20, 11, 4, 3, 8, 15, 31, 12] (0.9938333630561829,)
# [1, 23, 11, 3, 3, 8, 15, 17, 12] (0.9936666488647461,)
#
# [1, 20, 11, 4, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9938333630561829 0.9933000206947327
# [2, 20, 11, 4, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.00016666666488163173 0.0
# [2, 23, 11, 3, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9940000176429749 0.9919999837875366
# [1, 20, 11, 3, 3, 8, 15, 31, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9936666488647461 0.9925000071525574
# True
# 1.0 number of paired: 2 number of mutations: 0  d: 4  no change: 2
#
# Evolving activation:
# [2, 21, 7, 2, 4, 23, 22, 27, 27] (0.9963333606719971,)
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9958333373069763,)
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9953333139419556,)
# [2, 21, 7, 2, 4, 30, 21, 17, 23] (0.9933333396911621,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 30, 21, 27, 27]
# 0.9943333268165588 0.992900013923645
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 8, 19, 3, 3, 23, 22, 17, 27]
# 0.09783333539962769 0.09799999743700027
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 19, 2, 3, 23, 22, 27, 27]
# 0.9936666488647461 0.9914000034332275
# True
# 1.0 number of paired: 2 number of mutations: 0  d: 3  no change: 1
#
# [2, 21, 7, 2, 4, 23, 22, 27, 27] (0.9963333606719971,)
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9958333373069763,)
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9953333139419556,)
# [2, 21, 7, 2, 4, 30, 21, 27, 27] (0.9943333268165588,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 19, 2, 4, 30, 21, 17, 27]
# 0.09783333539962769 0.09799999743700027
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 7, 3, 3, 23, 21, 27, 23]
# 0.9938333630561829 0.9919999837875366
# False
# 1.0 number of paired: 1 number of mutations: 0  d: 2  no change: 2
#
# No improvements: 0.9958333373069763
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 27, 27]
# 0.9953333139419556 0.9933000206947327
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 17, 23]
# 0.9953333139419556 0.9941999912261963
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9956666827201843 0.9939000010490417
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 30, 21, 27, 27]
# 0.9940000176429749 0.9916999936103821
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9956666827201843 0.9936000108718872
# [2, 20, 11, 4, 3, 8, 15, 31, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9946666955947876 0.991599977016449
# [2, 23, 11, 3, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9943333268165588 0.9927999973297119
# [1, 20, 11, 4, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9943333268165588 0.9937000274658203
# Current surrogate: epochs 100 , samples 54000
# Evolving loss:
# [2, 23, 11, 3, 3, 8, 15, 17, 19] (0.9956666827201843,)
# [2, 20, 11, 4, 3, 8, 15, 31, 19] (0.9946666955947876,)
# [2, 23, 11, 3, 3, 8, 15, 31, 12] (0.9943333268165588,)
# [1, 20, 11, 4, 3, 8, 15, 31, 12] (0.9943333268165588,)
#
# False
# 1.0 number of paired: 0 number of mutations: 0  d: 3  no change: 1
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] (0.9956666827201843,)
# [2, 20, 11, 4, 3, 8, 15, 31, 19] (0.9946666955947876,)
# [2, 23, 11, 3, 3, 8, 15, 31, 12] (0.9943333268165588,)
# [1, 20, 11, 4, 3, 8, 15, 31, 12] (0.9943333268165588,)
#
# False
# 1.0 number of paired: 0 number of mutations: 0  d: 2  no change: 2
#
# Evolving activation:
# [2, 21, 7, 2, 4, 23, 22, 27, 27] (0.9953333139419556,)
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9953333139419556,)
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9956666827201843,)
# [2, 21, 7, 2, 4, 30, 21, 27, 27] (0.9940000176429749,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 8, 7, 3, 3, 23, 22, 27, 27]
# 0.11133333295583725 0.10279999673366547
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 19, 2, 3, 23, 21, 27, 23]
# 0.09783333539962769 0.09799999743700027
# True
# 1.0 number of paired: 1 number of mutations: 0  d: 3  no change: 1
#
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9956666827201843,)
# [2, 21, 7, 2, 4, 23, 22, 27, 27] (0.9953333139419556,)
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9953333139419556,)
# [2, 21, 7, 2, 4, 30, 21, 27, 27] (0.9940000176429749,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 8, 19, 2, 3, 23, 21, 17, 23]
# 0.09783333539962769 0.09799999743700027
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 19, 2, 3, 30, 22, 27, 23]
# 0.09783333539962769 0.09799999743700027
# False
# 1.0 number of paired: 1 number of mutations: 0  d: 2  no change: 2
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9959999918937683 0.9940000176429749
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 27, 27]
# 0.9956666827201843 0.9948999881744385
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 17, 23]
# 0.9955000281333923 0.9943000078201294
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 30, 21, 27, 27]
# 0.9934999942779541 0.9929999709129333
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9950000047683716 0.9933000206947327
# [2, 20, 11, 4, 3, 8, 15, 31, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9940000176429749 0.9921000003814697
# [2, 23, 11, 3, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9944999814033508 0.9926999807357788
# [1, 20, 11, 4, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9934999942779541 0.9919999837875366
# Current surrogate: epochs 100 , samples 54000
# Evolving loss:
# [2, 23, 11, 3, 3, 8, 15, 17, 19] (0.9950000047683716,)
# [2, 20, 11, 4, 3, 8, 15, 31, 19] (0.9940000176429749,)
# [2, 23, 11, 3, 3, 8, 15, 31, 12] (0.9944999814033508,)
# [1, 20, 11, 4, 3, 8, 15, 31, 12] (0.9934999942779541,)
#
# True
# 1.0 number of paired: 0 number of mutations: 0  d: 3  no change: 1
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] (0.9950000047683716,)
# [2, 23, 11, 3, 3, 8, 15, 31, 12] (0.9944999814033508,)
# [2, 20, 11, 4, 3, 8, 15, 31, 19] (0.9940000176429749,)
# [1, 20, 11, 4, 3, 8, 15, 31, 12] (0.9934999942779541,)
#
# [2, 23, 11, 4, 3, 8, 15, 31, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9943333268165588 0.9926000237464905
# [2, 23, 11, 4, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9931666851043701 0.9919000267982483
# True
# 1.0 number of paired: 1 number of mutations: 0  d: 3  no change: 2
#
# Evolving activation:
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9959999918937683,)
# [2, 21, 7, 2, 4, 23, 22, 27, 27] (0.9956666827201843,)
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9955000281333923,)
# [2, 21, 7, 2, 4, 30, 21, 27, 27] (0.9934999942779541,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 3, 3, 30, 22, 27, 27]
# 0.9929999709129333 0.9923999905586243
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 19, 2, 4, 30, 21, 17, 27]
# 0.09783333539962769 0.09799999743700027
# False
# 1.0 number of paired: 1 number of mutations: 0  d: 2  no change: 1
#
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9959999918937683,)
# [2, 21, 7, 2, 4, 23, 22, 27, 27] (0.9956666827201843,)
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9955000281333923,)
# [2, 21, 7, 2, 4, 30, 21, 27, 27] (0.9934999942779541,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 30, 22, 17, 27]
# 0.09783333539962769 0.09799999743700027
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 21, 27, 23]
# 0.09783333539962769 0.09799999743700027
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 7, 3, 4, 30, 22, 27, 27]
# 0.9936666488647461 0.9908000230789185
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 8, 7, 3, 4, 30, 21, 27, 27]
# 0.11133333295583725 0.10279999673366547
# True
# 1.0 number of paired: 2 number of mutations: 0  d: 2  no change: 2
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9951666593551636 0.9943000078201294
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 27, 27]
# 0.9956666827201843 0.9948999881744385
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 17, 23]
# 0.9956666827201843 0.9939000010490417
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 7, 3, 4, 30, 22, 27, 27]
# 0.9928333163261414 0.9918000102043152
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9958333373069763 0.9937000274658203
# [2, 23, 11, 3, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9944999814033508 0.9922999739646912
# [2, 23, 11, 4, 3, 8, 15, 31, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9938333630561829 0.9940000176429749
# [2, 20, 11, 4, 3, 8, 15, 31, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9941666722297668 0.9925000071525574
# Current surrogate: epochs 100 , samples 54000
# Evolving loss:
# [2, 23, 11, 3, 3, 8, 15, 17, 19] (0.9958333373069763,)
# [2, 23, 11, 3, 3, 8, 15, 31, 12] (0.9944999814033508,)
# [2, 23, 11, 4, 3, 8, 15, 31, 19] (0.9938333630561829,)
# [2, 20, 11, 4, 3, 8, 15, 31, 19] (0.9941666722297668,)
#
# True
# 1.0 number of paired: 0 number of mutations: 0  d: 3  no change: 1
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] (0.9958333373069763,)
# [2, 23, 11, 3, 3, 8, 15, 31, 12] (0.9944999814033508,)
# [2, 20, 11, 4, 3, 8, 15, 31, 19] (0.9941666722297668,)
# [2, 23, 11, 4, 3, 8, 15, 31, 19] (0.9938333630561829,)
#
# False
# 1.0 number of paired: 0 number of mutations: 0  d: 2  no change: 2
#
# Evolving activation:
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9951666593551636,)
# [2, 21, 7, 2, 4, 23, 22, 27, 27] (0.9956666827201843,)
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9956666827201843,)
# [6, 21, 7, 3, 4, 30, 22, 27, 27] (0.9928333163261414,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 30, 22, 27, 23]
# 0.09783333539962769 0.09799999743700027
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 7, 3, 4, 23, 22, 17, 27]
# 0.10499999672174454 0.11349999904632568
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 3, 3, 30, 21, 27, 27]
# 0.9944999814033508 0.9933000206947327
# True
# 1.0 number of paired: 2 number of mutations: 0  d: 2  no change: 1
#
# [2, 21, 7, 2, 4, 23, 22, 27, 27] (0.9956666827201843,)
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9956666827201843,)
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9951666593551636,)
# [2, 21, 7, 3, 3, 30, 21, 27, 27] (0.9944999814033508,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 3, 4, 30, 22, 17, 27]
# 0.9941666722297668 0.9909999966621399
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 3, 30, 22, 27, 23]
# 0.09783333539962769 0.09799999743700027
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 7, 3, 4, 23, 21, 27, 27]
# 0.9946666955947876 0.9926000237464905
# True
# 1.0 number of paired: 2 number of mutations: 0  d: 2  no change: 2
#
# No improvements: 0.9956666827201843
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 27, 27]
# 0.9951666593551636 0.9941999912261963
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 17, 23]
# 0.9955000281333923 0.9945999979972839
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9951666593551636 0.9937000274658203
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 7, 3, 4, 23, 21, 27, 27]
# 0.9940000176429749 0.9926999807357788
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9955000281333923 0.9939000010490417
# [2, 23, 11, 3, 3, 8, 15, 31, 12] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9936666488647461 0.9929999709129333
# [2, 20, 11, 4, 3, 8, 15, 31, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9940000176429749 0.9930999875068665
# [2, 23, 11, 4, 3, 8, 15, 31, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# 0.9940000176429749 0.9932000041007996
# Current surrogate: epochs 100 , samples 54000
# Evolving loss:
# [2, 23, 11, 3, 3, 8, 15, 17, 19] (0.9955000281333923,)
# [2, 23, 11, 3, 3, 8, 15, 31, 12] (0.9936666488647461,)
# [2, 20, 11, 4, 3, 8, 15, 31, 19] (0.9940000176429749,)
# [2, 23, 11, 4, 3, 8, 15, 31, 19] (0.9940000176429749,)
#
# True
# 1.0 number of paired: 0 number of mutations: 0  d: 3  no change: 1
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] (0.9955000281333923,)
# [2, 20, 11, 4, 3, 8, 15, 31, 19] (0.9940000176429749,)
# [2, 23, 11, 4, 3, 8, 15, 31, 19] (0.9940000176429749,)
# [2, 23, 11, 3, 3, 8, 15, 31, 12] (0.9936666488647461,)
#
# False
# 1.0 number of paired: 0 number of mutations: 0  d: 2  no change: 2
#
# Evolving activation:
# [2, 21, 7, 2, 4, 23, 22, 27, 27] (0.9951666593551636,)
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9955000281333923,)
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9951666593551636,)
# [6, 21, 7, 3, 4, 23, 21, 27, 27] (0.9940000176429749,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 7, 3, 3, 30, 21, 27, 27]
# 0.10499999672174454 0.11349999904632568
# True
# 1.0 number of paired: 1 number of mutations: 0  d: 2  no change: 1
#
# [2, 21, 7, 2, 4, 23, 22, 17, 23] (0.9955000281333923,)
# [2, 21, 7, 2, 4, 23, 22, 27, 27] (0.9951666593551636,)
# [6, 8, 19, 3, 3, 30, 21, 27, 27] (0.9951666593551636,)
# [6, 21, 7, 3, 4, 23, 21, 27, 27] (0.9940000176429749,)
#
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 8, 7, 3, 3, 23, 22, 27, 27]
# 0.10499999672174454 0.11349999904632568
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 7, 3, 3, 23, 22, 27, 27]
# 0.10499999672174454 0.11349999904632568
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 21, 7, 2, 4, 23, 22, 27, 27]
# 0.10499999672174454 0.11349999904632568
# False
# 1.0 number of paired: 2 number of mutations: 0  d: 1  no change: 2
#
# No improvements: 0.9955000281333923
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 17, 23]
# 0.9956666827201843 0.9940999746322632
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [2, 21, 7, 2, 4, 23, 22, 27, 27]
# 0.9950000047683716 0.9941999912261963
# [2, 23, 11, 3, 3, 8, 15, 17, 19] [6, 8, 19, 3, 3, 30, 21, 27, 27]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-6e02a657ac58> in <module>
#     187
#     188     for individual in population_pos:
# --> 189         individual.fitness.values = NeuroEvolution.evaluate(individual, models=[model_vgg1],
#     190                                       earlyTermination=earlyTermination, representation='pangaea',
#     191                                       epochs=epochs_v, sampleSize=sample_v,
#
# ~\PycharmProjects\SANE - V1\NeuroEvolution.py in evaluate(individual, models, earlyTermination, representation, sampleSize, epochs, callbaks, optimizationTask, evaluation, metric)
#     115             evaluation_model.create_model()
#     116             print(evaluation_model.loss.operators, evaluation_model.activation.function.operators)
# --> 117             evaluation_model.fit()
#     118             #print(model.loss_pos)
#     119             #model.createModel()
#
# ~\PycharmProjects\SANE - V1\NeuralNetwork.py in fit(self)
#      81             for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
#      82                 # print(type(epoch), type(train_step_counter))
# ---> 83                 loss_value = train_step(x_batch_train, y_batch_train, epoch + 1, False)
#      84                 train_step_counter += 1
#      85             # print(train_step_counter)
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~\Anaconda3\envs\GPU\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
def plotPAU(f):
    plotRange = np.linspace(-2, 2,1000)

    values = []
    for i in plotRange:
                    values.append(f.calculate(float(i)))
    plt.plot(plotRange, values)
    plt.xlim(-2,2)
    #plt.ylim(-4,4)
    plt.show()

def plotFunction(f):
    plotRange = np.linspace(-1, 1,1000)

    values = []
    for i in plotRange:
                    values.append(f.s2(float(i)))
    plt.plot(plotRange, values)
    plt.xlim(-1,1)
    #plt.ylim(-4,4)
    plt.show()

# %%
import matplotlib.pyplot as plt
plotFunction(Function([1, 15, 26, 1, 3, 9, 30, 8, 17]))
